# %% [markdown]
# ### Extra Visualizations for the presentation deck

# %%
import matplotlib.pyplot as plt

# %%
date =  ['September13',   'September12',   'September11',   'September10',   'September07',   'September06',   'September05',   'September04',   'August31',   'August30',   'August29',   'August28',   'August27',   'August24',   'August23',   'August22',   'August21',   'August20',   'August17',   'August16',   'August15',   'August14',   'August13']

# %%
nflix1 = [368.1499938964844, 369.95001220703125, 355.92999267578125, 348.4100036621094, 348.67999267578125, 346.4599914550781, 341.17999267578125, 363.6000061035156, 367.67999267578125, 370.9800109863281, 368.0400085449219, 368.489990234375, 364.5799865722656, 358.82000732421875, 339.1700134277344, 344.44000244140625, 338.0199890136719, 327.7300109863281, 316.7799987792969, 322.44000244140625, 326.3999938964844, 337.489990234375, 341.30999755859375]

# %%
nflix = [371.3494865422456, 344.6700134277344, 352.2699890136719, 342.20001220703125, 347.44000244140625, 360, 366.4700012207031, 370.6600036621094, 365, 367.20001220703125, 367.2300109863281, 367.1499938964844, 346, 348.1099853515625, 338.489990234375, 331, 314.6400146484375, 319.010009765625, 329.8999938964844, 334.0299987792969, 342.0899963378906, 339.8900146484375]

# %%
plt.plot( nflix, color='g')
plt.plot(nflix1, color='orange')
plt.xlabel('date')
plt.ylabel('netflix')
plt.title('Opening and Closing of Netflix Stocks')
plt.show()

# %% [markdown]
# ## **Analyst Data**
#
#
# ### Apple analyst prediction statistics
# #### Inference: Buy Apple Stocks

# %%
import matplotlib.pyplot as plt
labels = 'sell', 'hold', 'buy', 'strongbuy'
sizes = [0, 8, 20, 0]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Tesla analyst prediction statistics
# #### Inference: Sell Tesla Stocks

# %%
labels = 'sell', 'hold', 'buy', 'strongbuy'
sizes = [14, 12, 7, 0]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### CRM analyst prediction statistics
# #### Inference: Buy Salesforce Stocks

# %%
labels = 'sell', 'hold', 'buy', 'strongbuy'
sizes = [0, 4, 31, 1]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1
           , 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Netflix analyst prediction statistics
# #### Inference: Buy Netflix Stocks

# %%
labels = 'sell', 'hold', 'buy', 'strongbuy'
sizes = [4, 12, 31, 0]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()
